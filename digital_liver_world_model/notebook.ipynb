# %% [markdown]
# # Digital Liver World Model — Demo
#
# Trains a JEPA-style world model and evaluates it.

# %%
import sys, os
sys.path.insert(0, os.getcwd())
from config import Config
from train import train

cfg = Config(n_patients=100, epochs=20)
model, results = train(cfg)
print(results)
